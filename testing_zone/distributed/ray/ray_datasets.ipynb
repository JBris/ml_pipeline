# %% [markdown]
# Introduction

# %%
import ray

# Create a Dataset of Python objects.
ds = ray.data.range(200)
# -> Dataset(num_blocks=200, num_rows=10000, schema=<class 'int'>)

ds.take(5)
# -> [0, 1, 2, 3, 4]

ds.count()
# -> 10000

# Create a Dataset of Arrow records.
ds = ray.data.from_items([{"col1": i, "col2": str(i)} for i in range(200)])
# -> Dataset(num_blocks=200, num_rows=10000, schema={col1: int64, col2: string})

ds.show(5)
# -> {'col1': 0, 'col2': '0'}
# -> {'col1': 1, 'col2': '1'}
# -> {'col1': 2, 'col2': '2'}
# -> {'col1': 3, 'col2': '3'}
# -> {'col1': 4, 'col2': '4'}

ds.schema()
# Out:
# 2021-12-05 19:57:51,183	INFO services.py:1338 -- View the Ray dashboard at http://127.0.0.1:8265
# {'col1': 0, 'col2': '0'}
# {'col1': 1, 'col2': '1'}
# {'col1': 2, 'col2': '2'}
# {'col1': 3, 'col2': '3'}
# {'col1': 4, 'col2': '4'}
# col1: int64
# col2: string

# %%
import pandas as pd
import dask.dataframe as dd

# Create a Dataset from a list of Pandas DataFrame objects.
pdf = pd.DataFrame({"one": [1, 2, 3], "two": ["a", "b", "c"]})
ds = ray.data.from_pandas([pdf])

# Create a Dataset from a Dask-on-Ray DataFrame.
dask_df = dd.from_pandas(pdf, npartitions=10)
ds = ray.data.from_dask(dask_df)

# %%
ds = ray.data.range(10000)
ds = ds.map(lambda x: x * 2)
# -> Map Progress: 100%|████████████████████| 200/200 [00:00<00:00, 1123.54it/s]
# -> Dataset(num_blocks=200, num_rows=10000, schema=<class 'int'>)
ds.take(5)
# -> [0, 2, 4, 6, 8]

ds.filter(lambda x: x > 5).take(5)
# -> Map Progress: 100%|████████████████████| 200/200 [00:00<00:00, 1859.63it/s]
# -> [6, 8, 10, 12, 14]

ds.flat_map(lambda x: [x, -x]).take(5)
# -> Map Progress: 100%|████████████████████| 200/200 [00:00<00:00, 1568.10it/s]
# -> [0, 0, 2, -2, 4]
# Out:
# Map Progress: 100%|██████████| 200/200 [00:00<00:00, 324.52it/s]
# Map Progress: 100%|██████████| 200/200 [00:00<00:00, 481.75it/s]
# Map Progress: 100%|██████████| 200/200 [00:00<00:00, 425.79it/s]
# [0, 0, 2, -2, 4]

# %%
ds = ray.data.range_arrow(10000)
ds = ds.map_batches(
    lambda df: df.applymap(lambda x: x * 2), batch_format="pandas")
# -> Map Progress: 100%|████████████████████| 200/200 [00:00<00:00, 1927.62it/s]
ds.take(5)
# -> [{'value': 0}, {'value': 2}, ...]
# Out:
# Map Progress: 100%|██████████| 200/200 [00:01<00:00, 131.55it/s]
# [{'value': 0}, {'value': 2}, {'value': 4}, {'value': 6}, {'value': 8}]

# %%
@ray.remote
def consume(data) -> int:
    num_batches = 0
    for batch in data.iter_batches():
        num_batches += 1
    return num_batches

ds = ray.data.range(10000)
ray.get(consume.remote(ds))
# Out:
# 200

# %%
@ray.remote(num_gpus=1)
class Worker:
    def __init__(self, rank: int):
        pass

    def train(self, shard: ray.data.Dataset[int]) -> int:
        for batch in shard.iter_batches(batch_size=256):
            pass
        return shard.count()

workers = [Worker.remote(i) for i in range(16)]
# -> [Actor(Worker, ...), Actor(Worker, ...), ...]

ds = ray.data.range(10000)
# -> Dataset(num_blocks=200, num_rows=10000, schema=<class 'int'>)

shards = ds.split(n=16, locality_hints=workers)
# -> [Dataset(num_blocks=13, num_rows=650, schema=<class 'int'>),
#     Dataset(num_blocks=13, num_rows=650, schema=<class 'int'>), ...]

ray.get([w.train.remote(s) for s in shards])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3304/3655161914.py in <module>
#      19 #     Dataset(num_blocks=13, num_rows=650, schema=<class 'int'>), ...]
#      20
# ---> 21 ray.get([w.train.remote(s) for s in shards])
#
# ~\AppData\Local\Temp/ipykernel_3304/3655161914.py in <listcomp>(.0)
#      19 #     Dataset(num_blocks=13, num_rows=650, schema=<class 'int'>), ...]
#      20
# ---> 21 ray.get([w.train.remote(s) for s in shards])
#
# NameError: name 'w' is not defined
# (scheduler +40s) Tip: use `ray status` to view detailed cluster status. To disable these messages, set RAY_SCHEDULER_EVENTS=0.
# (scheduler +40s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0, 'GPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# 2021-12-05 19:58:31,739	WARNING worker.py:1245 -- The actor or task with ID ffffffffffffffff8764f7827bbd189d6e832eb401000000 cannot be scheduled right now. You can ignore this message if this Ray cluster is expected to auto-scale or if you specified a runtime_env for this actor or task, which may take time to install.  Otherwise, this is likely due to all cluster resources being claimed by actors. To resolve the issue, consider creating fewer actors or increasing the resources available to this Ray cluster.
# Required resources for this actor or task: {CPU: 1.000000}, {GPU: 1.000000}
# Available resources on this node: {3.000000/4.000000 CPU, 77736960.058594 GiB/77736960.058594 GiB memory, 0.000000/1.000000 GPU, 38868479.980469 GiB/38868479.980469 GiB object_store_memory, 1.000000/1.000000 node:127.0.0.1}
#  In total there are 0 pending tasks and 15 pending actors on this node.

# %% [markdown]
# Pipelines

# %%
def func1(i: int) -> int:
    return i + 1

def func2(i: int) -> int:
    return i * 2

def func3(i: int) -> int:
    return i % 3

# Create a dataset and then create a pipeline from it.
base = ray.data.range(1000000)
print(base)
# -> Dataset(num_blocks=200, num_rows=1000000, schema=<class 'int'>)
pipe = base.window(blocks_per_window=10)
print(pipe)
# -> DatasetPipeline(num_windows=20, num_stages=1)

# Applying transforms to pipelines adds more pipeline stages.
pipe = pipe.map(func1)
pipe = pipe.map(func2)
pipe = pipe.map(func3)
print(pipe)
# -> DatasetPipeline(num_windows=20, num_stages=4)

# Output can be pulled from the pipeline concurrently with its execution.
num_rows = 0
for row in pipe.iter_rows():
    num_rows += 1

print("Total num rows", num_rows)
# Out:
# Stage 0:   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
# Stage 1:   0%|          | 0/20 [00:00<?, ?it/s]
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#
# Stage 2:   0%|          | 0/20 [00:00<?, ?it/s]
#
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#
#
# Stage 3:   0%|          | 0/20 [00:00<?, ?it/s]
# Dataset(num_blocks=200, num_rows=1000000, schema=<class 'int'>)
# DatasetPipeline(num_windows=20, num_stages=1)
# DatasetPipeline(num_windows=20, num_stages=4)
# Stage 0:  10%|█         | 2/20 [00:00<00:02,  6.11it/s]
#
# Stage 2:   5%|▌         | 1/20 [00:00<00:10,  1.85it/s]
# Stage 0:  15%|█▌        | 3/20 [00:00<00:04,  3.44it/s]
#
#
# Stage 3:   5%|▌         | 1/20 [00:00<00:16,  1.13it/s]
#
# Stage 2:  10%|█         | 2/20 [00:01<00:09,  1.96it/s]
#
#
# Stage 3:  10%|█         | 2/20 [00:01<00:11,  1.56it/s]
# Stage 0:  20%|██        | 4/20 [00:01<00:07,  2.22it/s]
#
# Stage 2:  15%|█▌        | 3/20 [00:01<00:10,  1.66it/s]
#
#
# Stage 3:  15%|█▌        | 3/20 [00:01<00:10,  1.62it/s]
# Stage 0:  25%|██▌       | 5/20 [00:02<00:07,  1.97it/s]
#
# Stage 2:  20%|██        | 4/20 [00:02<00:09,  1.66it/s]
#
#
# Stage 3:  20%|██        | 4/20 [00:02<00:10,  1.53it/s]
# Stage 0:  30%|███       | 6/20 [00:02<00:07,  1.76it/s]
#
# Stage 2:  25%|██▌       | 5/20 [00:03<00:10,  1.45it/s]
# Stage 0:  35%|███▌      | 7/20 [00:03<00:07,  1.70it/s]
#
#
# Stage 3:  25%|██▌       | 5/20 [00:03<00:11,  1.29it/s]
#
# Stage 2:  30%|███       | 6/20 [00:03<00:09,  1.52it/s]
#
#
# Stage 3:  30%|███       | 6/20 [00:03<00:08,  1.59it/s]
# Stage 0:  40%|████      | 8/20 [00:04<00:07,  1.61it/s]
#
# Stage 2:  35%|███▌      | 7/20 [00:04<00:08,  1.59it/s]
#
#
# Stage 3:  35%|███▌      | 7/20 [00:04<00:07,  1.64it/s]
# Stage 0:  45%|████▌     | 9/20 [00:04<00:06,  1.60it/s]
#
# Stage 2:  40%|████      | 8/20 [00:04<00:07,  1.58it/s]
#
#
# Stage 3:  40%|████      | 8/20 [00:05<00:07,  1.61it/s]
# Stage 0:  50%|█████     | 10/20 [00:05<00:06,  1.65it/s][A
#
# Stage 2:  45%|████▌     | 9/20 [00:05<00:07,  1.54it/s]
#
#
# Stage 3:  45%|████▌     | 9/20 [00:05<00:06,  1.58it/s]
# Stage 0:  55%|█████▌    | 11/20 [00:05<00:05,  1.68it/s]
#
# Stage 2:  50%|█████     | 10/20 [00:06<00:05,  1.68it/s]
# Stage 0:  60%|██████    | 12/20 [00:06<00:04,  1.90it/s]
#
#
# Stage 3:  50%|█████     | 10/20 [00:06<00:06,  1.59it/s]
#
# Stage 2:  55%|█████▌    | 11/20 [00:06<00:05,  1.80it/s]
#
#
# Stage 3:  55%|█████▌    | 11/20 [00:06<00:04,  1.84it/s]
# Stage 0:  65%|██████▌   | 13/20 [00:06<00:03,  1.77it/s]
#
# Stage 2:  60%|██████    | 12/20 [00:07<00:04,  1.83it/s]
#
#
# Stage 3:  60%|██████    | 12/20 [00:07<00:04,  1.76it/s]
# Stage 0:  70%|███████   | 14/20 [00:07<00:03,  1.68it/s]
#
# Stage 2:  65%|██████▌   | 13/20 [00:07<00:04,  1.72it/s]
# Stage 0:  75%|███████▌  | 15/20 [00:08<00:02,  1.82it/s]
#
#
# Stage 3:  65%|██████▌   | 13/20 [00:08<00:04,  1.67it/s]
#
# Stage 2:  70%|███████   | 14/20 [00:08<00:03,  1.83it/s]
# Stage 0:  80%|████████  | 16/20 [00:08<00:02,  1.91it/s]
#
#
# Stage 3:  70%|███████   | 14/20 [00:08<00:03,  1.79it/s]
#
# Stage 2:  75%|███████▌  | 15/20 [00:08<00:02,  1.92it/s]
#
#
# Stage 3:  75%|███████▌  | 15/20 [00:08<00:02,  2.03it/s]
# Stage 0:  85%|████████▌ | 17/20 [00:09<00:01,  1.88it/s]
#
# Stage 2:  80%|████████  | 16/20 [00:09<00:02,  1.92it/s]
#
#
# Stage 3:  80%|████████  | 16/20 [00:09<00:02,  1.98it/s]
# Stage 0:  90%|█████████ | 18/20 [00:09<00:01,  1.89it/s]
#
# Stage 2:  85%|████████▌ | 17/20 [00:09<00:01,  1.92it/s]
#
#
# Stage 3:  85%|████████▌ | 17/20 [00:09<00:01,  1.97it/s]
# Stage 0:  95%|█████████▌| 19/20 [00:10<00:00,  1.78it/s]
#
# Stage 2:  90%|█████████ | 18/20 [00:10<00:01,  1.79it/s]
# Stage 0: 100%|██████████| 20/20 [00:10<00:00,  2.03it/s]
#
#
# Stage 3:  90%|█████████ | 18/20 [00:10<00:01,  1.82it/s]
#
# Stage 2:  95%|█████████▌| 19/20 [00:10<00:00,  2.03it/s]
#
#
# Stage 3:  95%|█████████▌| 19/20 [00:11<00:00,  1.94it/s]
# Stage 1: 100%|██████████| 20/20 [00:11<00:00,  1.93it/s]
#
# Stage 2: 100%|██████████| 20/20 [00:11<00:00,  2.05it/s]
#
#
# Stage 3: 100%|██████████| 20/20 [00:11<00:00,  1.76it/s]
# Stage 2: 100%|██████████| 20/20 [00:11<00:00,  1.76it/s]
# Stage 1: 100%|██████████| 20/20 [00:11<00:00,  1.75it/s]
# Stage 0: 100%|██████████| 20/20 [00:11<00:00,  1.75it/s]
# Total num rows 1000000
# (scheduler +3m30s) Warning: The following resource request cannot be scheduled right now: {'GPU': 1.0, 'CPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# 2021-12-05 19:39:32,851	WARNING worker.py:1245 -- The actor or task with ID fffffffffffffffff2a4a5104568b5c8a91d5f4001000000 cannot be scheduled right now. You can ignore this message if this Ray cluster is expected to auto-scale or if you specified a runtime_env for this actor or task, which may take time to install.  Otherwise, this is likely due to all cluster resources being claimed by actors. To resolve the issue, consider creating fewer actors or increasing the resources available to this Ray cluster.
# Required resources for this actor or task: {CPU: 1.000000}, {GPU: 1.000000}
# Available resources on this node: {3.000000/4.000000 CPU, 86470680.029297 GiB/86470680.029297 GiB memory, 0.000000/1.000000 GPU, 43235339.990234 GiB/43235339.990234 GiB object_store_memory, 1.000000/1.000000 node:127.0.0.1}
#  In total there are 0 pending tasks and 15 pending actors on this node.

# %%
import ray
from ray.data.dataset_pipeline import DatasetPipeline

# Equivalent to ray.data.range(1000).repeat(times=4)
source = ray.data.range(1000)
pipe = DatasetPipeline.from_iterable(
    [lambda: source, lambda: source, lambda: source, lambda: source])

# Equivalent to ray.data.range(1000).window(blocks_per_window=10)
splits = ray.data.range(1000, parallelism=200).split(20)
pipe = DatasetPipeline.from_iterable([lambda s=s: s for s in splits])

# %%
pipe = ray.data.from_items([0, 1, 2, 3, 4]) \
    .repeat(3) \
    .random_shuffle_each_window()
for i, epoch in enumerate(pipe.iter_epochs()):
    print("Epoch {}", i)
    for row in epoch.iter_rows():
        print(row)
# Out:
# Stage 0:   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# Stage 1:   0%|          | 0/3 [00:00<?, ?it/s]
# Stage 0: 100%|██████████| 1/1 [00:00<00:00, 12.60it/s]
# Stage 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Stage 0: 100%|██████████| 1/1 [00:00<00:00, 16.07it/s]
# Stage 0: 100%|██████████| 1/1 [00:00<00:00, 72.91it/s]
# Epoch {} 0
# 4
# 3
# 0
# 1
# 2
# Epoch {} 1
# 0
# 1
# 3
# 2
# 4
# Epoch {} 2
# 0
# 2
# 3
# 4
# 1
# (scheduler +4m6s) Warning: The following resource request cannot be scheduled right now: {'CPU': 1.0, 'GPU': 1.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# Stage 0: 100%|██████████| 3/3 [00:10<00:00, 14.58it/s]
# Stage 1: 100%|██████████| 3/3 [00:10<00:00, 10.97it/s]

# %%
ray.data.from_items([0, 1, 2, 3, 4]) \
    .repeat(2) \
    .random_shuffle_each_window() \
    .show_windows()
# Out:
# Stage 0:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Stage 1:   0%|          | 0/2 [00:00<?, ?it/s]
# Stage 1: 100%|██████████| 2/2 [00:00<00:00, 10.01it/s]
# Stage 0: 100%|██████████| 2/2 [00:00<00:00,  9.60it/s]
# ------ Epoch 0 ------
# === Window 0 ===
# 3
# 2
# 0
# 1
# 4
# ------ Epoch 1 ------
# === Window 1 ===
# 3
# 0
# 4
# 1
# 2

# %%
ray.data.from_items([0, 1, 2, 3, 4]) \
    .repeat(2) \
    .foreach_window(lambda w: w.random_shuffle()) \
    .show_windows()
# Out:
# Stage 0:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Stage 1:   0%|          | 0/2 [00:00<?, ?it/s]
# Stage 1: 100%|██████████| 2/2 [00:00<00:00, 14.08it/s]
# Stage 0: 100%|██████████| 2/2 [00:00<00:00, 13.61it/s]
# ------ Epoch 0 ------
# === Window 0 ===
# 0
# 1
# 4
# 3
# 2
# ------ Epoch 1 ------
# === Window 1 ===
# 2
# 3
# 0
# 1
# 4

# %%
def preprocess(image: bytes) -> bytes:
    return image

class BatchInferModel:
    def __init__(self):
        self.model = ImageNetModel()
    def __call__(self, batch: pd.DataFrame) -> pd.DataFrame:
        return self.model(batch)

# Load data from storage.
ds: Dataset = ray.data.read_binary_files("s3://bucket/image-dir")

# Preprocess the data.
ds = ds.map(preprocess)

# Apply GPU batch inference to the data.
ds = ds.map_batches(BatchInferModel, compute="actors", batch_size=256, num_gpus=1)
ds
# Save the output.
#ds.write_json("/tmp/results")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14428/2740895280.py in <module>
#       9
#      10 # Load data from storage.
# ---> 11 ds: Dataset = ray.data.read_binary_files("s3://bucket/image-dir")
#      12
#      13 # Preprocess the data.
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\read_api.py in read_binary_files(paths, include_paths, filesystem, parallelism, ray_remote_args, arrow_open_stream_args)
#     481         Dataset holding Arrow records read from the specified paths.
#     482     """
# --> 483     return read_datasource(
#     484         BinaryDatasource(),
#     485         parallelism=parallelism,
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\read_api.py in read_datasource(datasource, parallelism, ray_remote_args, _spread_resource_prefix, **read_args)
#     159     """
#     160
# --> 161     read_tasks = datasource.prepare_read(parallelism, **read_args)
#     162     context = DatasetContext.get_current()
#     163
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\datasource\file_based_datasource.py in prepare_read(self, parallelism, paths, filesystem, schema, open_stream_args, _block_udf, **reader_args)
#     125
#     126         paths, filesystem = _resolve_paths_and_filesystem(paths, filesystem)
# --> 127         paths, file_infos = _expand_paths(paths, filesystem)
#     128         file_sizes = [file_info.size for file_info in file_infos]
#     129
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\datasource\file_based_datasource.py in _expand_paths(paths, filesystem)
#     366     file_infos = []
#     367     for path in paths:
# --> 368         file_info = filesystem.get_file_info(path)
#     369         if file_info.type == FileType.Directory:
#     370             paths, file_infos_ = _expand_directory(path, filesystem)
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\pyarrow\_fs.pyx in pyarrow._fs.FileSystem.get_file_info()
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\pyarrow\error.pxi in pyarrow.lib.pyarrow_internal_check_status()
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\pyarrow\error.pxi in pyarrow.lib.check_status()
#
# OSError: When getting information for key 'image-dir' in bucket 'bucket': AWS Error [code 15]: No response body.

# %%
# Create a pipeline that loops over its source dataset indefinitely.
pipe: DatasetPipeline = ray.data \
    .read_datasource(...) \
    .repeat() \
    .random_shuffle_each_window()

@ray.remote(num_gpus=1)
def train_func(pipe: DatasetPipeline):
    model = MyModel()
    for batch in pipe.to_torch():
        model.fit(batch)

# Read from the pipeline in a remote training function.
ray.get(train_func.remote(pipe))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14428/2073455404.py in <module>
#       1 # Create a pipeline that loops over its source dataset indefinitely.
# ----> 2 pipe: DatasetPipeline = ray.data \
#       3     .read_datasource(...) \
#       4     .repeat() \
#       5     .random_shuffle_each_window()
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\read_api.py in read_datasource(datasource, parallelism, ray_remote_args, _spread_resource_prefix, **read_args)
#     159     """
#     160
# --> 161     read_tasks = datasource.prepare_read(parallelism, **read_args)
#     162     context = DatasetContext.get_current()
#     163
#
# AttributeError: 'ellipsis' object has no attribute 'prepare_read'

# %%
def train_func():
    # This is a dummy train function just iterating over the dataset shard.
    # You should replace this with your training logic.
    shard = ray.train.get_dataset_shard()
    for row in shard.iter_rows():
        print(row)

# Create a pipeline that loops over its source dataset indefinitely.
pipe: DatasetPipeline = ray.data \
    .read_parquet(...) \
    .repeat() \
    .random_shuffle_each_window()


# Pass in the pipeline to the Trainer.
# The Trainer will automatically split the DatasetPipeline for you.
trainer = Trainer(num_workers=8, backend="torch")
result = trainer.run(
    train_func,
    config={"worker_batch_size": 64, "num_epochs": 2},
    dataset=pipe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13152/791357472.py in <module>
#       7
#       8 # Create a pipeline that loops over its source dataset indefinitely.
# ----> 9 pipe: DatasetPipeline = ray.data \
#      10     .read_parquet(...) \
#      11     .repeat() \
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\read_api.py in read_parquet(paths, filesystem, columns, parallelism, ray_remote_args, _tensor_column_schema, **arrow_parquet_args)
#     269         arrow_parquet_args["_block_udf"] = _block_udf
#     270
# --> 271     return read_datasource(
#     272         ParquetDatasource(),
#     273         parallelism=parallelism,
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\read_api.py in read_datasource(datasource, parallelism, ray_remote_args, _spread_resource_prefix, **read_args)
#     159     """
#     160
# --> 161     read_tasks = datasource.prepare_read(parallelism, **read_args)
#     162     context = DatasetContext.get_current()
#     163
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\datasource\parquet_datasource.py in prepare_read(self, parallelism, paths, filesystem, columns, schema, _block_udf, **reader_args)
#      54         import numpy as np
#      55
# ---> 56         paths, filesystem = _resolve_paths_and_filesystem(paths, filesystem)
#      57         if len(paths) == 1:
#      58             paths = paths[0]
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\datasource\file_based_datasource.py in _resolve_paths_and_filesystem(paths, filesystem)
#     300     elif (not isinstance(paths, list)
#     301           or any(not isinstance(p, str) for p in paths)):
# --> 302         raise ValueError(
#     303             "paths must be a path string or a list of path strings.")
#     304     elif len(paths) == 0:
#
# ValueError: paths must be a path string or a list of path strings.
# 2021-12-05 19:47:05,375	ERROR worker.py:84 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::_map_block() (pid=1360, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#     new_block = fn(block)
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#     applied = fn(view)
#   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#     raise KeyError(list(np.compress(check, subset)))
# KeyError: ['feature_1']

# %%
# A Pandas DataFrame UDF for transforming the underlying blocks of a Dataset in parallel.
def transform_batch(df: pd.DataFrame):
    # Drop nulls.
    df = df.dropna(subset=["feature_1"])
    # Add new column.
    df["new_col"] = df["feature_1"] - 2 * df["feature_2"] + df["feature_3"] / 3
    # Transform existing column.
    df["feature_1"] = 2 * df["feature_1"] + 1
    # Drop column.
    df.drop(columns="feature_2", inplace=True)
    # One-hot encoding.
    categories = ["cat_1", "cat_2", "cat_3"]
    for category in categories:
        df[f"category_{category}"] = df["category"].map(
            collections.defaultdict(int, **{category: 1}))
    return df

# batch_format="pandas" tells Datasets to provide the transformer with blocks
# represented as Pandas DataFrames.
ds = ds.map_batches(transform_batch, batch_format="pandas")
# Out:
#  pid=13176) 2021-12-05 19:48:05,087	INFO worker.py:431 -- Task failed with retryable exception: TaskID(ef25d802e8c24317ffffffffffffffffffffffff01000000).
#  pid=13176) Traceback (most recent call last):
#  pid=13176)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13176)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13176)     new_block = fn(block)
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13176)     applied = fn(view)
#  pid=13176)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13176)     return func(*args, **kwargs)
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13176)     raise KeyError(list(np.compress(check, subset)))
#  pid=13176) KeyError: ['feature_1']
#  pid=1360) 2021-12-05 19:48:05,113	INFO worker.py:431 -- Task failed with retryable exception: TaskID(b9c64831282591f9ffffffffffffffffffffffff01000000).
#  pid=1360) Traceback (most recent call last):
#  pid=1360)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=1360)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=1360)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=1360)     new_block = fn(block)
#  pid=1360)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=1360)     applied = fn(view)
#  pid=1360)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=1360)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=1360)     return func(*args, **kwargs)
#  pid=1360)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=1360)     raise KeyError(list(np.compress(check, subset)))
#  pid=1360) KeyError: ['feature_1']
#  pid=13328) 2021-12-05 19:48:05,125	INFO worker.py:431 -- Task failed with retryable exception: TaskID(02bed209b72c305affffffffffffffffffffffff01000000).
#  pid=13328) Traceback (most recent call last):
#  pid=13328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13328)     new_block = fn(block)
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13328)     applied = fn(view)
#  pid=13328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13328)     return func(*args, **kwargs)
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13328)     raise KeyError(list(np.compress(check, subset)))
#  pid=13328) KeyError: ['feature_1']
#  pid=10020) 2021-12-05 19:48:05,121	INFO worker.py:431 -- Task failed with retryable exception: TaskID(faf123d8b1b35293ffffffffffffffffffffffff01000000).
#  pid=10020) Traceback (most recent call last):
#  pid=10020)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=10020)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=10020)     new_block = fn(block)
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=10020)     applied = fn(view)
#  pid=10020)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=10020)     return func(*args, **kwargs)
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=10020)     raise KeyError(list(np.compress(check, subset)))
#  pid=10020) KeyError: ['feature_1']
#  pid=1360) 2021-12-05 19:48:05,141	INFO worker.py:431 -- Task failed with retryable exception: TaskID(7fabc23126d27f51ffffffffffffffffffffffff01000000).
#  pid=1360) Traceback (most recent call last):
#  pid=1360)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=1360)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=1360)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=1360)     new_block = fn(block)
#  pid=1360)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=1360)     applied = fn(view)
#  pid=1360)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=1360)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=1360)     return func(*args, **kwargs)
#  pid=1360)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=1360)     raise KeyError(list(np.compress(check, subset)))
#  pid=1360) KeyError: ['feature_1']
#  pid=13176) 2021-12-05 19:48:05,169	INFO worker.py:431 -- Task failed with retryable exception: TaskID(e07eebba574c5c52ffffffffffffffffffffffff01000000).
#  pid=13176) Traceback (most recent call last):
#  pid=13176)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13176)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13176)     new_block = fn(block)
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13176)     applied = fn(view)
#  pid=13176)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13176)     return func(*args, **kwargs)
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13176)     raise KeyError(list(np.compress(check, subset)))
#  pid=13176) KeyError: ['feature_1']
#  pid=13176) 2021-12-05 19:48:05,190	INFO worker.py:431 -- Task failed with retryable exception: TaskID(bde90c6e4585812cffffffffffffffffffffffff01000000).
#  pid=13176) Traceback (most recent call last):
#  pid=13176)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13176)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13176)     new_block = fn(block)
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13176)     applied = fn(view)
#  pid=13176)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13176)     return func(*args, **kwargs)
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13176)     raise KeyError(list(np.compress(check, subset)))
#  pid=13176) KeyError: ['feature_1']
#  pid=1360) 2021-12-05 19:48:05,202	INFO worker.py:431 -- Task failed with retryable exception: TaskID(85186699e206774effffffffffffffffffffffff01000000).
#  pid=1360) Traceback (most recent call last):
#  pid=1360)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=1360)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=1360)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=1360)     new_block = fn(block)
#  pid=1360)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=1360)     applied = fn(view)
#  pid=1360)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=1360)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=1360)     return func(*args, **kwargs)
#  pid=1360)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=1360)     raise KeyError(list(np.compress(check, subset)))
#  pid=1360) KeyError: ['feature_1']
#  pid=13328) 2021-12-05 19:48:05,176	INFO worker.py:431 -- Task failed with retryable exception: TaskID(6c1e0b9bd7e2a3a6ffffffffffffffffffffffff01000000).
#  pid=13328) Traceback (most recent call last):
#  pid=13328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13328)     new_block = fn(block)
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13328)     applied = fn(view)
#  pid=13328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13328)     return func(*args, **kwargs)
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13328)     raise KeyError(list(np.compress(check, subset)))
#  pid=13328) KeyError: ['feature_1']
#  pid=10020) 2021-12-05 19:48:05,173	INFO worker.py:431 -- Task failed with retryable exception: TaskID(6346e12fbb9bd273ffffffffffffffffffffffff01000000).
#  pid=10020) Traceback (most recent call last):
#  pid=10020)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=10020)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=10020)     new_block = fn(block)
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=10020)     applied = fn(view)
#  pid=10020)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=10020)     return func(*args, **kwargs)
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=10020)     raise KeyError(list(np.compress(check, subset)))
#  pid=10020) KeyError: ['feature_1']
#  pid=12328) 2021-12-05 19:48:10,471	INFO worker.py:431 -- Task failed with retryable exception: TaskID(ef25d802e8c24317ffffffffffffffffffffffff01000000).
#  pid=12328) Traceback (most recent call last):
#  pid=12328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=12328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=12328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=12328)     new_block = fn(block)
#  pid=12328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=12328)     applied = fn(view)
#  pid=12328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=12328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=12328)     return func(*args, **kwargs)
#  pid=12328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=12328)     raise KeyError(list(np.compress(check, subset)))
#  pid=12328) KeyError: ['feature_1']
#  pid=12328) 2021-12-05 19:48:10,492	INFO worker.py:431 -- Task failed with retryable exception: TaskID(e07eebba574c5c52ffffffffffffffffffffffff01000000).
#  pid=12328) Traceback (most recent call last):
#  pid=12328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=12328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=12328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=12328)     new_block = fn(block)
#  pid=12328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=12328)     applied = fn(view)
#  pid=12328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=12328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=12328)     return func(*args, **kwargs)
#  pid=12328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=12328)     raise KeyError(list(np.compress(check, subset)))
#  pid=12328) KeyError: ['feature_1']
#  pid=13176) 2021-12-05 19:48:10,471	INFO worker.py:431 -- Task failed with retryable exception: TaskID(b9c64831282591f9ffffffffffffffffffffffff01000000).
#  pid=13176) Traceback (most recent call last):
#  pid=13176)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13176)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13176)     new_block = fn(block)
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13176)     applied = fn(view)
#  pid=13176)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13176)     return func(*args, **kwargs)
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13176)     raise KeyError(list(np.compress(check, subset)))
#  pid=13176) KeyError: ['feature_1']
#  pid=13176) 2021-12-05 19:48:10,492	INFO worker.py:431 -- Task failed with retryable exception: TaskID(7fabc23126d27f51ffffffffffffffffffffffff01000000).
#  pid=13176) Traceback (most recent call last):
#  pid=13176)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13176)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13176)     new_block = fn(block)
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13176)     applied = fn(view)
#  pid=13176)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13176)     return func(*args, **kwargs)
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13176)     raise KeyError(list(np.compress(check, subset)))
#  pid=13176) KeyError: ['feature_1']
#  pid=13328) 2021-12-05 19:48:10,484	INFO worker.py:431 -- Task failed with retryable exception: TaskID(faf123d8b1b35293ffffffffffffffffffffffff01000000).
#  pid=13328) Traceback (most recent call last):
#  pid=13328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13328)     new_block = fn(block)
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13328)     applied = fn(view)
#  pid=13328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13328)     return func(*args, **kwargs)
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13328)     raise KeyError(list(np.compress(check, subset)))
#  pid=13328) KeyError: ['feature_1']
#  pid=13328) 2021-12-05 19:48:10,509	INFO worker.py:431 -- Task failed with retryable exception: TaskID(6c1e0b9bd7e2a3a6ffffffffffffffffffffffff01000000).
#  pid=13328) Traceback (most recent call last):
#  pid=13328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13328)     new_block = fn(block)
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13328)     applied = fn(view)
#  pid=13328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13328)     return func(*args, **kwargs)
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13328)     raise KeyError(list(np.compress(check, subset)))
#  pid=13328) KeyError: ['feature_1']
#  pid=10020) 2021-12-05 19:48:10,472	INFO worker.py:431 -- Task failed with retryable exception: TaskID(02bed209b72c305affffffffffffffffffffffff01000000).
#  pid=10020) Traceback (most recent call last):
#  pid=10020)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=10020)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=10020)     new_block = fn(block)
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=10020)     applied = fn(view)
#  pid=10020)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=10020)     return func(*args, **kwargs)
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=10020)     raise KeyError(list(np.compress(check, subset)))
#  pid=10020) KeyError: ['feature_1']
#  pid=10020) 2021-12-05 19:48:10,492	INFO worker.py:431 -- Task failed with retryable exception: TaskID(6346e12fbb9bd273ffffffffffffffffffffffff01000000).
#  pid=10020) Traceback (most recent call last):
#  pid=10020)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=10020)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=10020)     new_block = fn(block)
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=10020)     applied = fn(view)
#  pid=10020)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=10020)     return func(*args, **kwargs)
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=10020)     raise KeyError(list(np.compress(check, subset)))
#  pid=10020) KeyError: ['feature_1']
#  pid=10020) 2021-12-05 19:48:10,515	INFO worker.py:431 -- Task failed with retryable exception: TaskID(85186699e206774effffffffffffffffffffffff01000000).
#  pid=10020) Traceback (most recent call last):
#  pid=10020)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=10020)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=10020)     new_block = fn(block)
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=10020)     applied = fn(view)
#  pid=10020)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=10020)     return func(*args, **kwargs)
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=10020)     raise KeyError(list(np.compress(check, subset)))
#  pid=10020) KeyError: ['feature_1']
#  pid=12328) 2021-12-05 19:48:10,509	INFO worker.py:431 -- Task failed with retryable exception: TaskID(bde90c6e4585812cffffffffffffffffffffffff01000000).
#  pid=12328) Traceback (most recent call last):
#  pid=12328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=12328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=12328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=12328)     new_block = fn(block)
#  pid=12328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=12328)     applied = fn(view)
#  pid=12328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=12328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=12328)     return func(*args, **kwargs)
#  pid=12328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=12328)     raise KeyError(list(np.compress(check, subset)))
#  pid=12328) KeyError: ['feature_1']
#  pid=13176) 2021-12-05 19:48:16,489	INFO worker.py:431 -- Task failed with retryable exception: TaskID(02bed209b72c305affffffffffffffffffffffff01000000).
#  pid=13176) Traceback (most recent call last):
#  pid=13176)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13176)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13176)     new_block = fn(block)
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13176)     applied = fn(view)
#  pid=13176)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13176)     return func(*args, **kwargs)
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13176)     raise KeyError(list(np.compress(check, subset)))
#  pid=13176) KeyError: ['feature_1']
#  pid=13176) 2021-12-05 19:48:16,514	INFO worker.py:431 -- Task failed with retryable exception: TaskID(e07eebba574c5c52ffffffffffffffffffffffff01000000).
#  pid=13176) Traceback (most recent call last):
#  pid=13176)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13176)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13176)     new_block = fn(block)
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13176)     applied = fn(view)
#  pid=13176)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13176)     return func(*args, **kwargs)
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13176)     raise KeyError(list(np.compress(check, subset)))
#  pid=13176) KeyError: ['feature_1']
#  pid=13176) 2021-12-05 19:48:16,534	INFO worker.py:431 -- Task failed with retryable exception: TaskID(bde90c6e4585812cffffffffffffffffffffffff01000000).
#  pid=13176) Traceback (most recent call last):
#  pid=13176)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13176)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13176)     new_block = fn(block)
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13176)     applied = fn(view)
#  pid=13176)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13176)     return func(*args, **kwargs)
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13176)     raise KeyError(list(np.compress(check, subset)))
#  pid=13176) KeyError: ['feature_1']
#  pid=1360) 2021-12-05 19:48:16,503	INFO worker.py:431 -- Task failed with retryable exception: TaskID(faf123d8b1b35293ffffffffffffffffffffffff01000000).
#  pid=1360) Traceback (most recent call last):
#  pid=1360)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=1360)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=1360)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=1360)     new_block = fn(block)
#  pid=1360)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=1360)     applied = fn(view)
#  pid=1360)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=1360)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=1360)     return func(*args, **kwargs)
#  pid=1360)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=1360)     raise KeyError(list(np.compress(check, subset)))
#  pid=1360) KeyError: ['feature_1']
#  pid=1360) 2021-12-05 19:48:16,533	INFO worker.py:431 -- Task failed with retryable exception: TaskID(85186699e206774effffffffffffffffffffffff01000000).
#  pid=1360) Traceback (most recent call last):
#  pid=1360)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=1360)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=1360)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=1360)     new_block = fn(block)
#  pid=1360)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=1360)     applied = fn(view)
#  pid=1360)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=1360)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=1360)     return func(*args, **kwargs)
#  pid=1360)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=1360)     raise KeyError(list(np.compress(check, subset)))
#  pid=1360) KeyError: ['feature_1']
#  pid=13328) 2021-12-05 19:48:16,492	INFO worker.py:431 -- Task failed with retryable exception: TaskID(b9c64831282591f9ffffffffffffffffffffffff01000000).
#  pid=13328) Traceback (most recent call last):
#  pid=13328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13328)     new_block = fn(block)
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13328)     applied = fn(view)
#  pid=13328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13328)     return func(*args, **kwargs)
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13328)     raise KeyError(list(np.compress(check, subset)))
#  pid=13328) KeyError: ['feature_1']
#  pid=13328) 2021-12-05 19:48:16,521	INFO worker.py:431 -- Task failed with retryable exception: TaskID(7fabc23126d27f51ffffffffffffffffffffffff01000000).
#  pid=13328) Traceback (most recent call last):
#  pid=13328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13328)     new_block = fn(block)
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13328)     applied = fn(view)
#  pid=13328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13328)     return func(*args, **kwargs)
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13328)     raise KeyError(list(np.compress(check, subset)))
#  pid=13328) KeyError: ['feature_1']
#  pid=10020) 2021-12-05 19:48:16,490	INFO worker.py:431 -- Task failed with retryable exception: TaskID(ef25d802e8c24317ffffffffffffffffffffffff01000000).
#  pid=10020) Traceback (most recent call last):
#  pid=10020)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=10020)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=10020)     new_block = fn(block)
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=10020)     applied = fn(view)
#  pid=10020)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=10020)     return func(*args, **kwargs)
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=10020)     raise KeyError(list(np.compress(check, subset)))
#  pid=10020) KeyError: ['feature_1']
#  pid=10020) 2021-12-05 19:48:16,514	INFO worker.py:431 -- Task failed with retryable exception: TaskID(6346e12fbb9bd273ffffffffffffffffffffffff01000000).
#  pid=10020) Traceback (most recent call last):
#  pid=10020)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=10020)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=10020)     new_block = fn(block)
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=10020)     applied = fn(view)
#  pid=10020)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=10020)     return func(*args, **kwargs)
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=10020)     raise KeyError(list(np.compress(check, subset)))
#  pid=10020) KeyError: ['feature_1']
#  pid=10020) 2021-12-05 19:48:16,534	INFO worker.py:431 -- Task failed with retryable exception: TaskID(6c1e0b9bd7e2a3a6ffffffffffffffffffffffff01000000).
#  pid=10020) Traceback (most recent call last):
#  pid=10020)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=10020)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=10020)     new_block = fn(block)
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=10020)     applied = fn(view)
#  pid=10020)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=10020)     return func(*args, **kwargs)
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=10020)     raise KeyError(list(np.compress(check, subset)))
#  pid=10020) KeyError: ['feature_1']
#  pid=12328) 2021-12-05 19:48:22,519	INFO worker.py:431 -- Task failed with retryable exception: TaskID(faf123d8b1b35293ffffffffffffffffffffffff01000000).
#  pid=12328) Traceback (most recent call last):
#  pid=12328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=12328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=12328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=12328)     new_block = fn(block)
#  pid=12328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=12328)     applied = fn(view)
#  pid=12328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=12328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=12328)     return func(*args, **kwargs)
#  pid=12328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=12328)     raise KeyError(list(np.compress(check, subset)))
#  pid=12328) KeyError: ['feature_1']
#  pid=13176) 2021-12-05 19:48:22,504	INFO worker.py:431 -- Task failed with retryable exception: TaskID(02bed209b72c305affffffffffffffffffffffff01000000).
#  pid=13176) Traceback (most recent call last):
#  pid=13176)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13176)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13176)     new_block = fn(block)
#  pid=13176)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13176)     applied = fn(view)
#  pid=13176)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13176)     return func(*args, **kwargs)
#  pid=13176)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13176)     raise KeyError(list(np.compress(check, subset)))
#  pid=13176) KeyError: ['feature_1']
#  pid=13328) 2021-12-05 19:48:22,516	INFO worker.py:431 -- Task failed with retryable exception: TaskID(b9c64831282591f9ffffffffffffffffffffffff01000000).
#  pid=13328) Traceback (most recent call last):
#  pid=13328)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=13328)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=13328)     new_block = fn(block)
#  pid=13328)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=13328)     applied = fn(view)
#  pid=13328)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=13328)     return func(*args, **kwargs)
#  pid=13328)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=13328)     raise KeyError(list(np.compress(check, subset)))
#  pid=13328) KeyError: ['feature_1']
#  pid=10020) 2021-12-05 19:48:22,503	INFO worker.py:431 -- Task failed with retryable exception: TaskID(ef25d802e8c24317ffffffffffffffffffffffff01000000).
#  pid=10020) Traceback (most recent call last):
#  pid=10020)   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#  pid=10020)   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#  pid=10020)     new_block = fn(block)
#  pid=10020)   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#  pid=10020)     applied = fn(view)
#  pid=10020)   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#  pid=10020)     return func(*args, **kwargs)
#  pid=10020)   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#  pid=10020)     raise KeyError(list(np.compress(check, subset)))
#  pid=10020) KeyError: ['feature_1']
# ---------------------------------------------------------------------------
# RayTaskError(KeyError)                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13152/2366480439.py in <module>
#      18 # batch_format="pandas" tells Datasets to provide the transformer with blocks
#      19 # represented as Pandas DataFrames.
# ---> 20 ds = ds.map_batches(transform_batch, batch_format="pandas")
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py in map_batches(self, fn, batch_size, compute, batch_format, **ray_remote_args)
#     235
#     236         return Dataset(
# --> 237             compute.apply(transform, ray_remote_args, self._blocks),
#     238             self._epoch)
#     239
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py in apply(self, fn, remote_args, blocks)
#      67                     pass
#      68             # Reraise the original task failure exception.
# ---> 69             raise e from None
#      70         return BlockList(list(new_blocks), list(new_metadata))
#      71
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py in apply(self, fn, remote_args, blocks)
#      53         new_metadata = list(new_metadata)
#      54         try:
# ---> 55             new_metadata = map_bar.fetch_until_complete(new_metadata)
#      56         except (ray.exceptions.RayTaskError, KeyboardInterrupt) as e:
#      57             # One or more mapper tasks failed, or we received a SIGINT signal
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\progress_bar.py in fetch_until_complete(self, refs)
#      56         while remaining:
#      57             done, remaining = ray.wait(remaining, fetch_local=True)
# ---> 58             for ref, result in zip(done, ray.get(done)):
#      59                 ref_to_result[ref] = result
#      60             self.update(len(done))
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\_private\client_mode_hook.py in wrapper(*args, **kwargs)
#     103             if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104                 return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105         return func(*args, **kwargs)
#     106
#     107     return wrapper
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\worker.py in get(object_refs, timeout)
#    1711                     worker.core_worker.dump_object_store_memory_usage()
#    1712                 if isinstance(value, RayTaskError):
# -> 1713                     raise value.as_instanceof_cause()
#    1714                 else:
#    1715                     raise value
#
# RayTaskError(KeyError): ray::_map_block() (pid=13176, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#     new_block = fn(block)
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#     applied = fn(view)
#   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#     raise KeyError(list(np.compress(check, subset)))
# KeyError: ['feature_1']
# 2021-12-05 19:48:28,495	ERROR worker.py:84 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::_map_block() (pid=10020, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#     new_block = fn(block)
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#     applied = fn(view)
#   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#     raise KeyError(list(np.compress(check, subset)))
# KeyError: ['feature_1']
# 2021-12-05 19:48:28,498	ERROR worker.py:84 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::_map_block() (pid=13176, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#     new_block = fn(block)
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#     applied = fn(view)
#   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#     raise KeyError(list(np.compress(check, subset)))
# KeyError: ['feature_1']
# 2021-12-05 19:48:28,502	ERROR worker.py:84 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::_map_block() (pid=13328, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#     new_block = fn(block)
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#     applied = fn(view)
#   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#     raise KeyError(list(np.compress(check, subset)))
# KeyError: ['feature_1']
# 2021-12-05 19:48:28,509	ERROR worker.py:84 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::_map_block() (pid=12328, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 625, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 629, in ray._raylet.execute_task
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#     new_block = fn(block)
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 220, in transform
#     applied = fn(view)
#   File "C:\Users\James\AppData\Local\Temp/ipykernel_13152/2366480439.py", line 4, in transform_batch
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\James\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py", line 5953, in dropna
#     raise KeyError(list(np.compress(check, subset)))
# KeyError: ['feature_1']
# 2021-12-05 19:48:28,513	ERROR worker.py:84 -- Unhandled error (suppress with RAY_IGNORE_UNHANDLED_ERRORS=1): ray::_map_block() (pid=13176, ip=127.0.0.1)
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\compute.py", line 23, in _map_block
#     new_block = fn(block)
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\dataset.py", line 212, in transform
#     view = BlockAccessor.for_block(view).to_pandas()
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\impl\arrow_block.py", line 224, in to_pandas
#     return self._table.to_pandas()
#   File "pyarrow\array.pxi", line 766, in pyarrow.lib._PandasConvertible.to_pandas
#   File "pyarrow\table.pxi", line 1815, in pyarrow.lib.Table._to_pandas
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\pyarrow\pandas_compat.py", line 789, in table_to_blockmanager
#     blocks = _table_to_blocks(options, table, categories, ext_columns_dtypes)
#   File "D:\anaconda3\envs\yourenvname\lib\site-packages\pyarrow\pandas_compat.py", line 1128, in _table_to_blocks
#     result = pa.lib.table_to_blocks(options, block_table, categories,
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ray::_map_block() (pid=13176, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 618, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 650, in ray._raylet.execute_task
# ray.exceptions.TaskCancelledError: Task: TaskID(6346e12fbb9bd273ffffffffffffffffffffffff01000000) was cancelled

# %%
ds: ray.data.Dataset = ray.data.from_items([
    {"A": x % 3, "B": 2 * x, "C": 3 * x}
    for x in range(10)])

# Group by the A column and calculate the per-group mean for B and C columns.
agg_ds: ray.data.Dataset = ds.groupby("A").mean(["B", "C"])
 
agg_ds.to_pandas()

# Global mean on B column.
ds.mean("B")

# Global mean on multiple columns.
ds.mean(["B", "C"])

# Multiple global aggregations on multiple columns.
from ray.data.aggregate import Mean, Std
ds.aggregate(Mean("B"), Std("B", ddof=0), Mean("C"), Std("C", ddof=0))
# Out:
# Sort Sample: 100%|██████████| 10/10 [00:00<00:00, 49.75it/s]
# GroupBy Map: 100%|██████████| 10/10 [00:00<00:00, 31.72it/s]
# GroupBy Reduce: 100%|██████████| 10/10 [00:00<00:00, 183.13it/s]
# GroupBy Map: 100%|██████████| 10/10 [00:00<00:00, 271.91it/s]
# GroupBy Reduce: 100%|██████████| 1/1 [00:00<00:00, 89.91it/s]
# GroupBy Map: 100%|██████████| 10/10 [00:00<00:00, 97.95it/s]
# GroupBy Reduce: 100%|██████████| 1/1 [00:00<00:00, 85.34it/s]
# GroupBy Map: 100%|██████████| 10/10 [00:00<00:00, 1009.90it/s]
# GroupBy Reduce: 100%|██████████| 1/1 [00:00<00:00, 73.55it/s]
# {'mean(B)': 9.0, 'std(B)': 5.744562646538029, 'mean(C)': 13.5, 'std(C)': 8.616843969807043}

# %%
# Impute missing values with the column mean.
b_mean = ds.mean("B")

def impute_b(df: pd.DataFrame):
    df["B"].fillna(b_mean)
    return df

ds = ds.map_batches(impute_b, batch_format="pandas")

# Standard scaling of all feature columns.
stats = ds.aggregate(Mean("B"), Std("B"), Mean("C"), Std("C"))

def batch_standard_scaler(df: pd.DataFrame):
    def column_standard_scaler(s: pd.Series):
        s_mean = stats[f"mean({s.name})"]
        s_std = stats[f"std({s.name})"]
        return (s - s_mean) / s_std

    cols = df.columns.difference(["A"])
    df.loc[:, cols] = df.loc[:, cols].transform(column_standard_scaler)
    return df

ds = ds.map_batches(batch_standard_scaler, batch_format="pandas")
# Out:
# GroupBy Map: 100%|██████████| 10/10 [00:00<00:00, 140.28it/s]
# GroupBy Reduce: 100%|██████████| 1/1 [00:00<00:00, 60.09it/s]
# Map Progress: 100%|██████████| 10/10 [00:00<00:00, 95.72it/s]
# GroupBy Map: 100%|██████████| 10/10 [00:00<00:00, 507.13it/s]
# GroupBy Reduce: 100%|██████████| 1/1 [00:00<00:00, 37.30it/s]
# Map Progress: 100%|██████████| 10/10 [00:00<00:00, 67.85it/s]

# %%
ds = ray.data.range(10)
# -> [0, 1, ..., 9]

# Global random shuffle.
ds = ds.random_shuffle()

# Scales to terabytes of data with the same simple API.
ds = ray.data.read_parquet("s3://ursa-labs-taxi-data")  # open, tabular, NYC taxi dataset

# Don't run this next one on your laptop; it will probably crash since it will
# try to read and shuffle ~99 GB of data!
ds = ds.random_shuffle()

# Per-epoch shuffling is as simple as changing where we invoke the shuffle:
#   - Before repeating => dataset is shuffled once.
#   - After repeating  => dataset is shuffled on every epoch.
num_epochs = 20

# Shuffle once, then repeat this once-shuffled dataset for num_epochs epochs.
ds.random_shuffle().repeat(num_epochs)

# Shuffle repeatedly, where the original dataset is shuffled into a different
# order at the beginning of each epoch.
ds.repeat(num_epochs).random_shuffle_each_window()
# -> DatasetPipeline(num_windows=10, num_stages=2)
# Out:
# Shuffle Map: 100%|██████████| 10/10 [00:00<00:00, 166.12it/s]
# Shuffle Reduce: 100%|██████████| 10/10 [00:00<00:00, 193.22it/s]
# Map Progress:   0%|          | 0/2 [02:32<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13152/3188846593.py in <module>
#       9
#      10 # Scales to terabytes of data with the same simple API.
# ---> 11 ds = ray.data.read_parquet("s3://ursa-labs-taxi-data")  # open, tabular, NYC taxi dataset
#      12 # -> Dataset(num_blocks=125, num_rows=1547741381, schema={
#      13 #        vendor_id: string, pickup_at: timestamp[us], dropoff_at: timestamp[us],
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\read_api.py in read_parquet(paths, filesystem, columns, parallelism, ray_remote_args, _tensor_column_schema, **arrow_parquet_args)
#     269         arrow_parquet_args["_block_udf"] = _block_udf
#     270
# --> 271     return read_datasource(
#     272         ParquetDatasource(),
#     273         parallelism=parallelism,
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\read_api.py in read_datasource(datasource, parallelism, ray_remote_args, _spread_resource_prefix, **read_args)
#     159     """
#     160
# --> 161     read_tasks = datasource.prepare_read(parallelism, **read_args)
#     162     context = DatasetContext.get_current()
#     163
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\datasource\parquet_datasource.py in prepare_read(self, parallelism, paths, filesystem, columns, schema, _block_udf, **reader_args)
#     129             inferred_schema = schema
#     130         read_tasks = []
# --> 131         serialized_pieces = [cloudpickle.dumps(p) for p in pq_ds.pieces]
#     132         if len(pq_ds.pieces) > PARALLELIZE_META_FETCH_THRESHOLD:
#     133             metadata = _fetch_metadata_remotely(serialized_pieces)
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\data\datasource\parquet_datasource.py in <listcomp>(.0)
#     129             inferred_schema = schema
#     130         read_tasks = []
# --> 131         serialized_pieces = [cloudpickle.dumps(p) for p in pq_ds.pieces]
#     132         if len(pq_ds.pieces) > PARALLELIZE_META_FETCH_THRESHOLD:
#     133             metadata = _fetch_metadata_remotely(serialized_pieces)
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\cloudpickle\cloudpickle_fast.py in dumps(obj, protocol, buffer_callback)
#      71                 file, protocol=protocol, buffer_callback=buffer_callback
#      72             )
# ---> 73             cp.dump(obj)
#      74             return file.getvalue()
#      75
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\cloudpickle\cloudpickle_fast.py in dump(self, obj)
#     618     def dump(self, obj):
#     619         try:
# --> 620             return Pickler.dump(self, obj)
#     621         except RuntimeError as e:
#     622             if "recursion" in e.args[0]:
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\ray\cloudpickle\cloudpickle_fast.py in reducer_override(self, obj)
#     662             self.proto = int(protocol)
#     663
# --> 664         def reducer_override(self, obj):
#     665             """Type-agnostic reducing callback for function and classes.
#     666
#
# KeyboardInterrupt:

# %% [markdown]
# Dask

# %%
import ray
from ray.util.dask import ray_dask_get
import dask
import dask.array as da
import dask.dataframe as dd
import numpy as np
import pandas as pd

# Start Ray.
# Tip: If connecting to an existing cluster, use ray.init(address="auto").
ray.init(ignore_reinit_error=True)

d_arr = da.from_array(np.random.randint(0, 1000, size=(256, 256)))

# The Dask scheduler submits the underlying task graph to Ray.
d_arr.mean().compute(scheduler=ray_dask_get)

# Set the scheduler to ray_dask_get in your config so you don't have to
# specify it on each compute call.
dask.config.set(scheduler=ray_dask_get)

df = dd.from_pandas(
    pd.DataFrame(
        np.random.randint(0, 100, size=(1024, 2)), columns=["age", "grade"]),
    npartitions=2)
df.groupby(["age"]).mean().compute()

ray.shutdown()
# Out:
# 2021-12-05 19:50:18,098	INFO worker.py:852 -- Calling ray.init() again after it has already been called.

# %%
df
# Out:
# Dask DataFrame Structure:
#                  age  grade
# npartitions=2
# 0              int32  int32
# 512              ...    ...
# 1023             ...    ...
# Dask Name: from_pandas, 2 tasks
