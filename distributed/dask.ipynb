# %%
import dask
import dask.dataframe as dd
from dask.distributed import Client, wait, LocalCluster
import dask_ml
import dask.array as da
from dask_ml.model_selection import train_test_split
from scipy.stats import uniform, loguniform
from dask_ml.wrappers import ParallelPostFit
from dask_ml.model_selection import HyperbandSearchCV, GridSearchCV

# %%
client = Client(LocalCluster())
client
# Out:
# <Client: 'tcp://127.0.0.1:60851' processes=4 threads=4, memory=7.87 GiB>

# %%
df = dd.read_csv("../data/day.csv").drop("dteday", axis = 1)
df
# Out:
# Dask DataFrame Structure:
#               instant season     yr   mnth holiday weekday workingday weathersit     temp    atemp      hum windspeed casual registered    cnt
# npartitions=1
#                 int64  int64  int64  int64   int64   int64      int64      int64  float64  float64  float64   float64  int64      int64  int64
#                   ...    ...    ...    ...     ...     ...        ...        ...      ...      ...      ...       ...    ...        ...    ...
# Dask Name: drop_by_shallow_copy, 2 tasks

# %%
def take_samples(df, frac):
    return df.sample(frac = frac)

fut = []  
for i in range(5):
    samples = client.submit(take_samples, df, 0.1) 
    fut.append(samples) 
    wait(fut)

# %%
samples = []
for f in fut:
    samples.append(f.result())
sample = samples[0]

# %%
sample.compute()
# Out:
#      instant  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 655      656       4   1    10        0        3           1           1
# 578      579       3   1     8        0        3           1           1
# 637      638       4   1     9        0        6           0           1
# 715      716       4   1    12        0        0           0           2
# 43        44       1   0     2        0        0           0           1
# ..       ...     ...  ..   ...      ...      ...         ...         ...
# 364      365       1   0    12        0        6           0           1
# 174      175       3   0     6        0        5           1           1
# 521      522       2   1     6        0        2           1           2
# 525      526       2   1     6        0        6           0           1
# 705      706       4   1    12        0        4           1           1
#
#          temp     atemp       hum  windspeed  casual  registered   cnt
# 655  0.455833  0.450108  0.692917   0.101371     979        6482  7461
# 578  0.717500  0.667308  0.677500   0.141179    1074        6506  7580
# 637  0.542500  0.530296  0.542917   0.227604    2589        5966  8555
# 715  0.362500  0.369938  0.838750   0.100742     538        3248  3786
# 43   0.316522  0.324113  0.457391   0.260883     397        1192  1589
# ..        ...       ...       ...        ...     ...         ...   ...
# 364  0.410000  0.414121  0.615833   0.220154     665        1820  2485
# 174  0.724167  0.656583  0.573333   0.222025     969        4022  4991
# 521  0.540833  0.525892  0.613333   0.209575     968        6033  7001
# 525  0.710833  0.648367  0.437083   0.144287    2708        4790  7498
# 705  0.255833  0.258204  0.508750   0.174754     340        5035  5375
#
# [73 rows x 15 columns]

# %%
sample.groupby("season").apply(lambda x: x["temp"].mean()).compute()
# Out:
# `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
# season
# 1    0.308133
# 2    0.538553
# 3    0.743650
# 4    0.445375
# dtype: float64

# %%
train, test = sample.random_split([0.8, 0.2])
X = train.drop("temp", axis = 1)
y = train["temp"]

# %% [markdown]
# Cluster

# %%
from  dask_ml.cluster import KMeans
cluster = KMeans(n_clusters=2).fit(train.to_dask_array(lengths = True))

# %% [markdown]
# Incremental learning

# %%
from dask_ml.wrappers import Incremental
from sklearn.linear_model import SGDRegressor, SGDClassifier

estimator = SGDRegressor(random_state=10, max_iter=100)
reg = Incremental(estimator)
reg.fit(X, y)
reg.estimator_.score(X, y)
# Out:
# -0.25571081601792933

# %% [markdown]
# Naive Bayes

# %%
from dask_ml import datasets
from dask_ml.naive_bayes import GaussianNB

X, y = datasets.make_classification(chunks=50)
gnb = GaussianNB()
gnb.fit(X, y)
gnb.predict_proba(X) #.compute()
# Out:
# dask.array<exp, shape=(100, 2), dtype=float64, chunksize=(50, 1), chunktype=numpy.ndarray>

# %% [markdown]
# Pipeline

# %%
from sklearn.pipeline import Pipeline  # regular scikit-learn pipeline
from dask_ml.cluster import KMeans
from dask_ml.decomposition import PCA

estimators = [('reduce_dim', PCA()), ('nb', GaussianNB())]
pipe = Pipeline(estimators)
pipe.fit(X, y)
pipe.predict_proba(X) #.compute()
# Out:
# dask.array<exp, shape=(100, 2), dtype=float64, chunksize=(50, 1), chunktype=numpy.ndarray>

# %% [markdown]
# Cross Validation and Hyper Parameter Search

# %%
from dask_ml.linear_model import LogisticRegression

X, y = datasets.make_classification(chunks=20)
X_train, X_test, y_train, y_test = train_test_split(X, y)
params = {
    "penalty": ["l2", "l1"],
    "fit_intercept": [True, False]
}

est = ParallelPostFit(LogisticRegression())
est = LogisticRegression()
search = HyperbandSearchCV(est, params, random_state=0)

search.fit(X_train, y_train, classes=[0, 1]);
search.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3076/1810097061.py in <module>
#      15 search = HyperbandSearchCV(est, params, random_state=0)
#      16
# ---> 17 search.fit(X_train, y_train, classes=[0, 1]);
#      18 search.score(X_test, y_test)
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\dask_ml\model_selection\_incremental.py in fit(self, X, y, **fit_params)
#     724         client = default_client()
#     725         if not client.asynchronous:
# --> 726             return client.sync(self._fit, X, y, **fit_params)
#     727         return self._fit(X, y, **fit_params)
#     728
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\distributed\client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     866             return future
#     867         else:
# --> 868             return sync(
#     869                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     870             )
#
# D:\anaconda3\envs\yourenvname\lib\site-packages\distributed\utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     327     else:
#     328         while not e.is_set():
# --> 329             e.wait(10)
#     330     if error[0]:
#     331         typ, exc, tb = error[0]
#
# D:\anaconda3\envs\yourenvname\lib\threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# D:\anaconda3\envs\yourenvname\lib\threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
